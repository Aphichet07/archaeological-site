# %%
import numpy as np
import matplotlib.pyplot as plt 
from plyfile import PlyData
import open3d as o3d
import torch
from torch.utils.data import Dataset, DataLoader
import os
from sklearn.preprocessing import StandardScaler
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.cuda.amp import autocast, GradScaler
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
PLY_PATH = os.path.join(os.getcwd(), "..", "data", "processed", "WatCahi_labeled.ply")

# %%
pcd = PlyData.read(PLY_PATH)

# %%
def load_heritage_ply(file_path):
    print(f"Loading {file_path} ...")
    plydata = PlyData.read(file_path)
    vertex_data = plydata['vertex'].data
    
    coords = np.vstack((vertex_data['x'], vertex_data['y'], vertex_data['z'])).T
    
    colors = np.vstack((vertex_data['red'], vertex_data['green'], vertex_data['blue'])).T / 255.0
    
    geom_features = np.vstack((
        vertex_data['scalar_Roughness_(0.05)'],
        vertex_data['scalar_Mean_curvature_(0.05)'],
        vertex_data['scalar_Normal_change_rate_(0.05)'],
        vertex_data['scalar_Anisotropy_(0.05)'],
        vertex_data['scalar_Planarity_(0.05)'],
        vertex_data['scalar_Linearity_(0.05)'],
        vertex_data['scalar_Surface_variation_(0.05)']
    )).T
    
    X = np.hstack((coords, colors, geom_features))
    
    labels_matrix = np.vstack((
        vertex_data['scalar_Intact_Brick'],      # Class 0
        vertex_data['scalar_Material_Spalling'], # Class 1
        vertex_data['scalar_Moderate_Crack'],    # Class 2
        vertex_data['scalar_Severe_Crack']       # Class 3
    )).T
    
    Y = np.argmax(labels_matrix, axis=1)
    
    print(f"Data Loaded Successfully!")
    print(f"Feature Matrix (X) shape: {X.shape}") # (3576852, 13)
    print(f"Label Vector (Y) shape: {Y.shape}")   # (3576852,)
    
    return X, Y

# %%
X,Y = load_heritage_ply(PLY_PATH)
# Out:
# Loading c:\Users\babxk\Documents\GitHub\archaeological-site\notebook\..\data\processed\WatCahi_labeled.ply ...
# Data Loaded Successfully!
# Feature Matrix (X) shape: (3576852, 13)
# Label Vector (Y) shape: (3576852,)

# %%
def radial_train_test_split(X, Y, test_size=0.2,start_angle_offset=90):

    
    coords_xy = X[:, 0:2]
    
    centroid_x, centroid_y = np.median(coords_xy, axis=0)
    print(f"Pagoda Centroid estimated at: X={centroid_x:.2f}, Y={centroid_y:.2f}")
    
    angles_rad = np.arctan2(coords_xy[:, 1] - centroid_y, coords_xy[:, 0] - centroid_x)
    
    angles_deg = np.degrees(angles_rad)
    angles_deg = np.mod(angles_deg + 360 + start_angle_offset, 360) 
    
    test_angle_span = 360 * test_size
    test_mask = angles_deg <= test_angle_span
    train_mask = ~test_mask
    
    X_train, Y_train = X[train_mask], Y[train_mask]
    X_test, Y_test = X[test_mask], Y[test_mask]
    
    print(f"Train Set: {len(Y_train)} points ({len(Y_train)/len(Y)*100:.1f}%)")
    print(f"Test Set: {len(Y_test)} points ({len(Y_test)/len(Y)*100:.1f}%)")
    
    print("\nClass Distribution Train:")
    unique, counts = np.unique(Y_train, return_counts=True)
    print(dict(zip(unique, counts)))
    
    print("Class Distribution Test:")
    unique, counts = np.unique(Y_test, return_counts=True)
    print(dict(zip(unique, counts)))
    
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = radial_train_test_split(X, Y, test_size=0.2)
# Out:
# Performing Radial (Angular) Split for Pagoda...
# Pagoda Centroid estimated at: X=5.13, Y=0.14
# Train Set: 2684069 points (75.0%)
# Test Set: 892783 points (25.0%)
#
# Class Distribution Train:
# {np.int64(0): np.int64(114039), np.int64(1): np.int64(2570030)}
# Class Distribution Test:
# {np.int64(0): np.int64(24000), np.int64(1): np.int64(868783)}

# %%
class HeritagePointCloudDataset(Dataset):
    def __init__(self, X_features, Y_labels, block_size=1.0, num_points=4096, min_points_per_block=1024):

        self.block_size = block_size
        self.num_points = num_points
        self.min_points_per_block = min_points_per_block
        
        # Standardize Geometric Features
        print("Standardizing Geometric Features...")
        self.scaler = StandardScaler()
        self.X_processed = X_features.copy() 
        self.X_processed[:, 6:13] = self.scaler.fit_transform(self.X_processed[:, 6:13])
        
        # หั่น Block
        print("Partitioning Point Cloud into Blocks...")
        self.blocks_data = self._partition_into_blocks(self.X_processed, Y_labels)
        print(f"Total valid blocks ready for training: {len(self.blocks_data)}")

    def _partition_into_blocks(self, X, Y):
        coords = X[:, 0:2] 
        coord_min = np.min(coords, axis=0)
        
        grid_indices = np.floor((coords - coord_min) / self.block_size).astype(int)
        
        # สร้าง Unique ID สำหรับแต่ละ Block
        grid_keys = np.array([f"{gx}_{gy}" for gx, gy in grid_indices])
        unique_keys = np.unique(grid_keys)
        
        blocks = []
        for key in unique_keys:
            point_idx = np.where(grid_keys == key)[0]
            
            if len(point_idx) < self.min_points_per_block:
                continue
                
            blocks.append({
                'X': X[point_idx, :],
                'Y': Y[point_idx]
            })
            
        return blocks

    def __len__(self):
        return len(self.blocks_data)

    def __getitem__(self, idx):
        block = self.blocks_data[idx]
        block_X = block['X']
        block_Y = block['Y']
        
        num_points_in_block = block_X.shape[0]
        
        if num_points_in_block >= self.num_points:
            selected_idx = np.random.choice(num_points_in_block, self.num_points, replace=False)
        else:
            selected_idx = np.random.choice(num_points_in_block, self.num_points, replace=True)
            
        sampled_X = block_X[selected_idx, :]
        sampled_Y = block_Y[selected_idx]
        
        # --- Zero-Centering ---
        xyz = sampled_X[:, 0:3]
        centroid = np.mean(xyz, axis=0) 
        sampled_X[:, 0:3] = xyz - centroid # Centroid อยู่ที่ (0,0,0)
        
        # Output shape: tensor_X -> [13, 8192], tensor_Y -> [8192]
        tensor_X = torch.tensor(sampled_X, dtype=torch.float32).transpose(0, 1)
        tensor_Y = torch.tensor(sampled_Y, dtype=torch.long)                    
        
        return tensor_X, tensor_Y

# %%
train_dataset = HeritagePointCloudDataset(X_train, Y_train, block_size=1.0)
test_dataset = HeritagePointCloudDataset(X_test, Y_test, block_size=1.0)
# Out:
# Standardizing Geometric Features...
# Partitioning Point Cloud into Blocks...
# Total valid blocks ready for training: 54
# Standardizing Geometric Features...
# Partitioning Point Cloud into Blocks...
# Total valid blocks ready for training: 19

# %%
def create_dataloaders(X_train, Y_train, X_test, Y_test, batch_size=4):
    
    train_dataset = HeritagePointCloudDataset(
        X_features=X_train, 
        Y_labels=Y_train, 
        block_size=1.0, 
        num_points=8192, 
        min_points_per_block=1024
    )
    
    test_dataset = HeritagePointCloudDataset(
        X_features=X_test, 
        Y_labels=Y_test, 
        block_size=1.0, 
        num_points=8192, 
        min_points_per_block=1024
    )
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    
    return train_loader, test_loader

# %%
train_loader, test_loader = create_dataloaders(X_train, Y_train, X_test, Y_test, batch_size=8)
# Out:
# Standardizing Geometric Features...
# Partitioning Point Cloud into Blocks...
# Total valid blocks ready for training: 54
# Standardizing Geometric Features...
# Partitioning Point Cloud into Blocks...
# Total valid blocks ready for training: 19

# %%
def calculate_class_weights(Y_train, num_classes=4):
    unique, counts = np.unique(Y_train, return_counts=True)
    total_points = len(Y_train)
    
    weights = np.zeros(num_classes, dtype=np.float32)
    for cls, count in zip(unique, counts):
        weights[cls] = total_points / (num_classes * count)
    
    print(f"Class Weights: {weights}")
    return torch.tensor(weights, dtype=torch.float32)

# %%
class_weights = calculate_class_weights(Y_train)
# Out:
# Class Weights: [5.8841033  0.26109317 0.         0.        ]

# %%
criterion = torch.nn.CrossEntropyLoss(weight=class_weights.cuda())

# %%
class FocalLoss(torch.nn.Module):
    def __init__(self, alpha=None, gamma=2.0):
        """
        alpha: Tensor ของน้ำหนักแต่ละคลาส (class_weights ที่เราคำนวณไว้)
        gamma: ความดุดันในการเพ่งเล็งคลาสที่ทายยาก (มาตรฐานคือ 2.0)
        """
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, weight=self.alpha, reduction='none')
        
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss
        
        return focal_loss.mean()

# %%
class Conv1dBNReLU(nn.Module):
    """ 1D Conv + BatchNorm + LeakyReLU """
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size=1, bias=False)
        self.bn = nn.BatchNorm1d(out_channels)
        self.relu = nn.LeakyReLU(0.2, inplace=True)

    def forward(self, x):
        return self.relu(self.bn(self.conv(x)))

# %%
class MaxCapacityPointSeg(nn.Module):
    def __init__(self, num_classes=4, in_channels=13):
        super().__init__()
        # Encoder
        self.mlp1 = Conv1dBNReLU(in_channels, 128)
        self.mlp2 = Conv1dBNReLU(128, 256)
        self.mlp3 = Conv1dBNReLU(256, 512)
        self.mlp4 = Conv1dBNReLU(512, 512)
        self.mlp5 = Conv1dBNReLU(512, 1024) 

        # Decoder & Segmentation Head
        # Feature 128+256+512+1024+2048 = 3968
        # บวกกับ Global Feature 2048 รวมเป็น 6016 Channels 
        self.fc1 = Conv1dBNReLU(3456, 512)
        self.fc2 = Conv1dBNReLU(512, 256)
        self.fc3 = Conv1dBNReLU(256, 128)
        self.fc4 = Conv1dBNReLU(128, 128)
        
        self.classifier = nn.Conv1d(128, num_classes, kernel_size=1)

    def forward(self, x):
        # x shape: [Batch, Features(13), Points(8192)]
        num_points = x.size(2)

        # --- Encoder ---
        f1 = self.mlp1(x)    # [B, 128, N]
        f2 = self.mlp2(f1)   # [B, 256, N]
        f3 = self.mlp3(f2)   # [B, 512, N]
        f4 = self.mlp4(f3)   # [B, 1024, N]
        f5 = self.mlp5(f4)   # [B, 2048, N]

        # --- lobal Context ---
        global_feat = torch.max(f5, dim=2, keepdim=True)[0] # [B, 2048, 1]
        
        global_feat = global_feat.repeat(1, 1, num_points)  # [B, 2048, N]

        # --- Dense Concatenation ---
        concat_feat = torch.cat([f1, f2, f3, f4, f5, global_feat], dim=1) # [B, 6016, N]

        # --- Decoder ---
        out = self.fc1(concat_feat)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)
        
        logits = self.classifier(out) # [B, 4, N]
        
        return logits

# %%
model = MaxCapacityPointSeg(num_classes=4, in_channels=13).cuda()

# %%
def train_max_acc_fast(model, train_loader, num_epochs=100, class_weights=None):
    model = model.cuda()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
    criterion = FocalLoss(alpha=class_weights.cuda(), gamma=2.0)

    scaler = GradScaler() 
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.cuda(), targets.cuda()
            optimizer.zero_grad()
            
            
            with autocast():
                logits = model(inputs) 
                loss = criterion(logits, targets) 
            
           
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            
            total_loss += loss.item()
            
           
            if batch_idx % 10 == 0:
                print(f"Batch [{batch_idx}/{len(train_loader)}] Loss: {loss.item():.4f}")

# %%
train_max_acc_fast(model, train_loader, num_epochs=400, class_weights=class_weights)
# Out:
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\3000919803.py:7: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\3000919803.py:17: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Batch [0/6] Loss: 0.1363
# Batch [0/6] Loss: 0.1308
# Batch [0/6] Loss: 0.0775
# Batch [0/6] Loss: 0.1523
# Batch [0/6] Loss: 0.0706
# Batch [0/6] Loss: 0.1010
# Batch [0/6] Loss: 0.1697
# Batch [0/6] Loss: 0.0710
# Batch [0/6] Loss: 0.0473
# Batch [0/6] Loss: 0.1355
# Batch [0/6] Loss: 0.0373
# Batch [0/6] Loss: 0.0431
# Batch [0/6] Loss: 0.0437
# Batch [0/6] Loss: 0.0840
# Batch [0/6] Loss: 0.0610
# Batch [0/6] Loss: 0.0396
# Batch [0/6] Loss: 0.0644
# Batch [0/6] Loss: 0.0514
# Batch [0/6] Loss: 0.0631
# Batch [0/6] Loss: 0.0450
# Batch [0/6] Loss: 0.0489
# Batch [0/6] Loss: 0.0456
# Batch [0/6] Loss: 0.0448
# Batch [0/6] Loss: 0.0336
# Batch [0/6] Loss: 0.0266
# Batch [0/6] Loss: 0.0574
# Batch [0/6] Loss: 0.1150
# Batch [0/6] Loss: 0.0605
# Batch [0/6] Loss: 0.0675
# Batch [0/6] Loss: 0.0413
# Batch [0/6] Loss: 0.0406
# Batch [0/6] Loss: 0.1038
# Batch [0/6] Loss: 0.0402
# Batch [0/6] Loss: 0.0236
# Batch [0/6] Loss: 0.0849
# Batch [0/6] Loss: 0.0296
# Batch [0/6] Loss: 0.0242
# Batch [0/6] Loss: 0.0276
# Batch [0/6] Loss: 0.0286
# Batch [0/6] Loss: 0.0224
# Batch [0/6] Loss: 0.0334
# Batch [0/6] Loss: 0.0784
# Batch [0/6] Loss: 0.0458
# Batch [0/6] Loss: 0.0211
# Batch [0/6] Loss: 0.0290
# Batch [0/6] Loss: 0.0222
# Batch [0/6] Loss: 0.0227
# Batch [0/6] Loss: 0.0391
# Batch [0/6] Loss: 0.0467
# Batch [0/6] Loss: 0.0280
# Batch [0/6] Loss: 0.0244
# Batch [0/6] Loss: 0.0457
# Batch [0/6] Loss: 0.0297
# Batch [0/6] Loss: 0.0510
# Batch [0/6] Loss: 0.0212
# Batch [0/6] Loss: 0.0333
# Batch [0/6] Loss: 0.0191
# Batch [0/6] Loss: 0.0417
# Batch [0/6] Loss: 0.0325
# Batch [0/6] Loss: 0.0240
# Batch [0/6] Loss: 0.0334
# Batch [0/6] Loss: 0.0288
# Batch [0/6] Loss: 0.0299
# Batch [0/6] Loss: 0.0249
# Batch [0/6] Loss: 0.0467
# Batch [0/6] Loss: 0.0280
# Batch [0/6] Loss: 0.0263
# Batch [0/6] Loss: 0.0666
# Batch [0/6] Loss: 0.0258
# Batch [0/6] Loss: 0.0276
# Batch [0/6] Loss: 0.0165
# Batch [0/6] Loss: 0.0383
# Batch [0/6] Loss: 0.0290
# Batch [0/6] Loss: 0.0316
# Batch [0/6] Loss: 0.0224
# Batch [0/6] Loss: 0.0183
# Batch [0/6] Loss: 0.0398
# Batch [0/6] Loss: 0.0272
# Batch [0/6] Loss: 0.0184
# Batch [0/6] Loss: 0.0341
# Batch [0/6] Loss: 0.0194
# Batch [0/6] Loss: 0.0205
# Batch [0/6] Loss: 0.0316
# Batch [0/6] Loss: 0.0199
# Batch [0/6] Loss: 0.0349
# Batch [0/6] Loss: 0.0162
# Batch [0/6] Loss: 0.0256
# Batch [0/6] Loss: 0.0188
# Batch [0/6] Loss: 0.0425
# Batch [0/6] Loss: 0.0238
# Batch [0/6] Loss: 0.0102
# Batch [0/6] Loss: 0.0177
# Batch [0/6] Loss: 0.0517
# Batch [0/6] Loss: 0.0475
# Batch [0/6] Loss: 0.0277
# Batch [0/6] Loss: 0.0232
# Batch [0/6] Loss: 0.0554
# Batch [0/6] Loss: 0.0286
# Batch [0/6] Loss: 0.0234
# Batch [0/6] Loss: 0.0217
# Batch [0/6] Loss: 0.0272
# Batch [0/6] Loss: 0.0327
# Batch [0/6] Loss: 0.0358
# Batch [0/6] Loss: 0.0183
# Batch [0/6] Loss: 0.0245
# Batch [0/6] Loss: 0.0176
# Batch [0/6] Loss: 0.0252
# Batch [0/6] Loss: 0.0158
# Batch [0/6] Loss: 0.0125
# Batch [0/6] Loss: 0.0115
# Batch [0/6] Loss: 0.0302
# Batch [0/6] Loss: 0.0248
# Batch [0/6] Loss: 0.0334
# Batch [0/6] Loss: 0.0334
# Batch [0/6] Loss: 0.0601
# Batch [0/6] Loss: 0.0548
# Batch [0/6] Loss: 0.0185
# Batch [0/6] Loss: 0.0374
# Batch [0/6] Loss: 0.0223
# Batch [0/6] Loss: 0.0095
# Batch [0/6] Loss: 0.0295
# Batch [0/6] Loss: 0.0190
# Batch [0/6] Loss: 0.0157
# Batch [0/6] Loss: 0.0158
# Batch [0/6] Loss: 0.0089
# Batch [0/6] Loss: 0.0190
# Batch [0/6] Loss: 0.0314
# Batch [0/6] Loss: 0.0260
# Batch [0/6] Loss: 0.0165
# Batch [0/6] Loss: 0.0194
# Batch [0/6] Loss: 0.0366
# Batch [0/6] Loss: 0.0385
# Batch [0/6] Loss: 0.0167
# Batch [0/6] Loss: 0.0132
# Batch [0/6] Loss: 0.0176
# Batch [0/6] Loss: 0.0182
# Batch [0/6] Loss: 0.0291
# Batch [0/6] Loss: 0.0150
# Batch [0/6] Loss: 0.0157
# Batch [0/6] Loss: 0.0091
# Batch [0/6] Loss: 0.0110
# Batch [0/6] Loss: 0.0330
# Batch [0/6] Loss: 0.0179
# Batch [0/6] Loss: 0.0292
# Batch [0/6] Loss: 0.0136
# Batch [0/6] Loss: 0.0114
# Batch [0/6] Loss: 0.0143
# Batch [0/6] Loss: 0.0257
# Batch [0/6] Loss: 0.0261
# Batch [0/6] Loss: 0.0300
# Batch [0/6] Loss: 0.1572
# Batch [0/6] Loss: 0.0277
# Batch [0/6] Loss: 0.1087
# Batch [0/6] Loss: 0.0388
# Batch [0/6] Loss: 0.0374
# Batch [0/6] Loss: 0.0225
# Batch [0/6] Loss: 0.0417
# Batch [0/6] Loss: 0.0420
# Batch [0/6] Loss: 0.0284
# Batch [0/6] Loss: 0.0265
# Batch [0/6] Loss: 0.0162
# Batch [0/6] Loss: 0.0192
# Batch [0/6] Loss: 0.0197
# Batch [0/6] Loss: 0.0682
# Batch [0/6] Loss: 0.0341
# Batch [0/6] Loss: 0.0307
# Batch [0/6] Loss: 0.0244
# Batch [0/6] Loss: 0.0235
# Batch [0/6] Loss: 0.0256
# Batch [0/6] Loss: 0.0312
# Batch [0/6] Loss: 0.0368
# Batch [0/6] Loss: 0.0172
# Batch [0/6] Loss: 0.0248
# Batch [0/6] Loss: 0.0238
# Batch [0/6] Loss: 0.0296
# Batch [0/6] Loss: 0.0289
# Batch [0/6] Loss: 0.0276
# Batch [0/6] Loss: 0.0122
# Batch [0/6] Loss: 0.0065
# Batch [0/6] Loss: 0.0358
# Batch [0/6] Loss: 0.0193
# Batch [0/6] Loss: 0.0279
# Batch [0/6] Loss: 0.0086
# Batch [0/6] Loss: 0.0201
# Batch [0/6] Loss: 0.0097
# Batch [0/6] Loss: 0.0287
# Batch [0/6] Loss: 0.0260
# Batch [0/6] Loss: 0.0368
# Batch [0/6] Loss: 0.0133
# Batch [0/6] Loss: 0.0140
# Batch [0/6] Loss: 0.0315
# Batch [0/6] Loss: 0.0120
# Batch [0/6] Loss: 0.0075
# Batch [0/6] Loss: 0.0100
# Batch [0/6] Loss: 0.0119
# Batch [0/6] Loss: 0.0059
# Batch [0/6] Loss: 0.0200
# Batch [0/6] Loss: 0.0080
# Batch [0/6] Loss: 0.0062
# Batch [0/6] Loss: 0.0192
# Batch [0/6] Loss: 0.0304
# Batch [0/6] Loss: 0.0474
# Batch [0/6] Loss: 0.0279
# Batch [0/6] Loss: 0.0303
# Batch [0/6] Loss: 0.0223
# Batch [0/6] Loss: 0.0195
# Batch [0/6] Loss: 0.0250
# Batch [0/6] Loss: 0.0213
# Batch [0/6] Loss: 0.0271
# Batch [0/6] Loss: 0.0316
# Batch [0/6] Loss: 0.0214
# Batch [0/6] Loss: 0.0466
# Batch [0/6] Loss: 0.0489
# Batch [0/6] Loss: 0.0145
# Batch [0/6] Loss: 0.0169
# Batch [0/6] Loss: 0.0272
# Batch [0/6] Loss: 0.0223
# Batch [0/6] Loss: 0.0093
# Batch [0/6] Loss: 0.0083
# Batch [0/6] Loss: 0.0183
# Batch [0/6] Loss: 0.0143
# Batch [0/6] Loss: 0.0162
# Batch [0/6] Loss: 0.0099
# Batch [0/6] Loss: 0.0115
# Batch [0/6] Loss: 0.0187
# Batch [0/6] Loss: 0.0107
# Batch [0/6] Loss: 0.0092
# Batch [0/6] Loss: 0.0094
# Batch [0/6] Loss: 0.0166
# Batch [0/6] Loss: 0.0207
# Batch [0/6] Loss: 0.0245
# Batch [0/6] Loss: 0.0264
# Batch [0/6] Loss: 0.0207
# Batch [0/6] Loss: 0.0191
# Batch [0/6] Loss: 0.0150
# Batch [0/6] Loss: 0.0180
# Batch [0/6] Loss: 0.0207
# Batch [0/6] Loss: 0.0202
# Batch [0/6] Loss: 0.0094
# Batch [0/6] Loss: 0.0246
# Batch [0/6] Loss: 0.0178
# Batch [0/6] Loss: 0.0197
# Batch [0/6] Loss: 0.0310
# Batch [0/6] Loss: 0.0350
# Batch [0/6] Loss: 0.0223
# Batch [0/6] Loss: 0.0246
# Batch [0/6] Loss: 0.0109
# Batch [0/6] Loss: 0.0272
# Batch [0/6] Loss: 0.0079
# Batch [0/6] Loss: 0.0260
# Batch [0/6] Loss: 0.0178
# Batch [0/6] Loss: 0.0154
# Batch [0/6] Loss: 0.0084
# Batch [0/6] Loss: 0.0180
# Batch [0/6] Loss: 0.0211
# Batch [0/6] Loss: 0.0207
# Batch [0/6] Loss: 0.0082
# Batch [0/6] Loss: 0.0142
# Batch [0/6] Loss: 0.0110
# Batch [0/6] Loss: 0.0134
# Batch [0/6] Loss: 0.0132
# Batch [0/6] Loss: 0.0193
# Batch [0/6] Loss: 0.0269
# Batch [0/6] Loss: 0.0152
# Batch [0/6] Loss: 0.0253
# Batch [0/6] Loss: 0.0186
# Batch [0/6] Loss: 0.0142
# Batch [0/6] Loss: 0.0251
# Batch [0/6] Loss: 0.0095
# Batch [0/6] Loss: 0.0105
# Batch [0/6] Loss: 0.0232
# Batch [0/6] Loss: 0.0120
# Batch [0/6] Loss: 0.0217
# Batch [0/6] Loss: 0.0157
# Batch [0/6] Loss: 0.0064
# Batch [0/6] Loss: 0.0087
# Batch [0/6] Loss: 0.0213
# Batch [0/6] Loss: 0.0220
# Batch [0/6] Loss: 0.0284
# Batch [0/6] Loss: 0.0232
# Batch [0/6] Loss: 0.0141
# Batch [0/6] Loss: 0.0284
# Batch [0/6] Loss: 0.0125
# Batch [0/6] Loss: 0.0201
# Batch [0/6] Loss: 0.0332
# Batch [0/6] Loss: 0.0123
# Batch [0/6] Loss: 0.0206
# Batch [0/6] Loss: 0.0103
# Batch [0/6] Loss: 0.0079
# Batch [0/6] Loss: 0.0174
# Batch [0/6] Loss: 0.0273
# Batch [0/6] Loss: 0.0074
# Batch [0/6] Loss: 0.0203
# Batch [0/6] Loss: 0.0243
# Batch [0/6] Loss: 0.0162
# Batch [0/6] Loss: 0.0213
# Batch [0/6] Loss: 0.0182
# Batch [0/6] Loss: 0.0239
# Batch [0/6] Loss: 0.0123
# Batch [0/6] Loss: 0.0117
# Batch [0/6] Loss: 0.0205
# Batch [0/6] Loss: 0.0137
# Batch [0/6] Loss: 0.0236
# Batch [0/6] Loss: 0.0248
# Batch [0/6] Loss: 0.0327
# Batch [0/6] Loss: 0.0105
# Batch [0/6] Loss: 0.0159
# Batch [0/6] Loss: 0.0236
# Batch [0/6] Loss: 0.0118
# Batch [0/6] Loss: 0.0081
# Batch [0/6] Loss: 0.0181
# Batch [0/6] Loss: 0.0193
# Batch [0/6] Loss: 0.0178
# Batch [0/6] Loss: 0.0150
# Batch [0/6] Loss: 0.0137
# Batch [0/6] Loss: 0.0225
# Batch [0/6] Loss: 0.0208
# Batch [0/6] Loss: 0.0361
# Batch [0/6] Loss: 0.0123
# Batch [0/6] Loss: 0.0076
# Batch [0/6] Loss: 0.0168
# Batch [0/6] Loss: 0.0170
# Batch [0/6] Loss: 0.0149
# Batch [0/6] Loss: 0.0170
# Batch [0/6] Loss: 0.0088
# Batch [0/6] Loss: 0.0316
# Batch [0/6] Loss: 0.0105
# Batch [0/6] Loss: 0.0074
# Batch [0/6] Loss: 0.0103
# Batch [0/6] Loss: 0.0031
# Batch [0/6] Loss: 0.0151
# Batch [0/6] Loss: 0.0101
# Batch [0/6] Loss: 0.0295
# Batch [0/6] Loss: 0.0112
# Batch [0/6] Loss: 0.0137
# Batch [0/6] Loss: 0.0145
# Batch [0/6] Loss: 0.0166
# Batch [0/6] Loss: 0.0073
# Batch [0/6] Loss: 0.0235
# Batch [0/6] Loss: 0.0101
# Batch [0/6] Loss: 0.0173
# Batch [0/6] Loss: 0.0133
# Batch [0/6] Loss: 0.0182
# Batch [0/6] Loss: 0.0072
# Batch [0/6] Loss: 0.0181
# Batch [0/6] Loss: 0.0159
# Batch [0/6] Loss: 0.0209
# Batch [0/6] Loss: 0.0389
# Batch [0/6] Loss: 0.0095
# Batch [0/6] Loss: 0.0360
# Batch [0/6] Loss: 0.0148
# Batch [0/6] Loss: 0.0152
# Batch [0/6] Loss: 0.0253
# Batch [0/6] Loss: 0.0308
# Batch [0/6] Loss: 0.0216
# Batch [0/6] Loss: 0.0140
# Batch [0/6] Loss: 0.0153
# Batch [0/6] Loss: 0.0215
# Batch [0/6] Loss: 0.0201
# Batch [0/6] Loss: 0.0131
# Batch [0/6] Loss: 0.0100
# Batch [0/6] Loss: 0.0230
# Batch [0/6] Loss: 0.0064
# Batch [0/6] Loss: 0.0105
# Batch [0/6] Loss: 0.0039
# Batch [0/6] Loss: 0.0061
# Batch [0/6] Loss: 0.0216
# Batch [0/6] Loss: 0.0291
# Batch [0/6] Loss: 0.0065
# Batch [0/6] Loss: 0.0193
# Batch [0/6] Loss: 0.0477
# Batch [0/6] Loss: 0.0580
# Batch [0/6] Loss: 0.0328
# Batch [0/6] Loss: 0.0599
# Batch [0/6] Loss: 0.0424
# Batch [0/6] Loss: 0.0261
# Batch [0/6] Loss: 0.0386
# Batch [0/6] Loss: 0.0416
# Batch [0/6] Loss: 0.0481
# Batch [0/6] Loss: 0.0329
# Batch [0/6] Loss: 0.0286
# Batch [0/6] Loss: 0.0232
# Batch [0/6] Loss: 0.0479
# Batch [0/6] Loss: 0.0311
# Batch [0/6] Loss: 0.0180
# Batch [0/6] Loss: 0.0348
# Batch [0/6] Loss: 0.0304
# Batch [0/6] Loss: 0.0355
# Batch [0/6] Loss: 0.0353
# Batch [0/6] Loss: 0.0186
# Batch [0/6] Loss: 0.0161
# Batch [0/6] Loss: 0.0194
# Batch [0/6] Loss: 0.0250
# Batch [0/6] Loss: 0.0214
# Batch [0/6] Loss: 0.0442
# Batch [0/6] Loss: 0.0187
# Batch [0/6] Loss: 0.0155
# Batch [0/6] Loss: 0.0126
# Batch [0/6] Loss: 0.0257
# Batch [0/6] Loss: 0.0176

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# %%
def evaluate_model(model, test_loader, num_classes=4):
    model.eval() 
    
    all_preds = []
    all_targets = []
    
    class_names = ['0_Intact_Brick', '1_Material_Spalling', '2_Moderate_Crack', '3_Severe_Crack']
    
    with torch.no_grad(): 
        for inputs, targets in test_loader:
            inputs = inputs.cuda()
            targets = targets.cuda()
            
            logits = model(inputs)            # [Batch, 4, Points]
            preds = torch.argmax(logits, dim=1) # [Batch, Points]
            
            all_preds.append(preds.cpu().numpy().flatten())
            all_targets.append(targets.cpu().numpy().flatten())
            
    all_preds = np.concatenate(all_preds)
    all_targets = np.concatenate(all_targets)
    
    print("\n" + "="*50)
    print(" Classification Report ")
    print("="*50)
    print(classification_report(all_targets, all_preds, labels=[0, 1, 2, 3], target_names=class_names, digits=4, zero_division=0))
    
    print("\n" + "="*50)
    print(" Intersection over Union (IoU)")
    print("="*50)
    ious = []
    for c in range(num_classes):
        intersection = np.sum((all_preds == c) & (all_targets == c))
        union = np.sum((all_preds == c) | (all_targets == c))
        iou = intersection / union if union > 0 else np.nan
        ious.append(iou)
        print(f"[{class_names[c]}] IoU: {iou*100:.2f}%")
        
    print("-" * 30)
    print(f"Mean IoU (mIoU): {np.nanmean(ious)*100:.2f}%\n")
    
    cm = confusion_matrix(all_targets, all_preds)
    
    return cm, class_names

# %%
def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(10, 8))
    
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
    
    sns.heatmap(cm_percent, annot=True, fmt='.1f', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names)
    
    plt.title('Confusion Matrix (%)', fontsize=16, pad=20)
    plt.ylabel('Actual Label (ของจริง)', fontsize=12)
    plt.xlabel('Predicted Label (โมเดลทาย)', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
def visualize_prediction_3d(model, test_loader, num_points=4096):

    model.eval()
    inputs, targets = next(iter(test_loader)) # ดึงมาแค่ 1 Batch แรก
    
    with torch.no_grad():
        logits = model(inputs.cuda())
        preds = torch.argmax(logits, dim=1).cpu()
    
    block_idx = 0
    xyz = inputs[block_idx, 0:3, :].numpy() # [3, N] -> แกน X, Y, Z
    true_labels = targets[block_idx].numpy()
    pred_labels = preds[block_idx].numpy()
    
    fig = plt.figure(figsize=(16, 7))
    
    # 0: เทา(ปกติ), 1: ส้ม(Spalling), 2: แดงอ่อน(Moderate), 3: แดงเข้ม(Severe)
    colors = {0: '#B0BEC5', 1: '#FFB74D', 2: '#E57373', 3: '#B71C1C'}
    true_c = [colors[l] for l in true_labels]
    pred_c = [colors[l] for l in pred_labels]
    
    ax1 = fig.add_subplot(121, projection='3d')
    ax1.scatter(xyz[0], xyz[1], xyz[2], c=true_c, s=5, alpha=0.8)
    ax1.set_title("Ground Truth", fontsize=14)
    ax1.axis('off') 
    
    ax2 = fig.add_subplot(122, projection='3d')
    ax2.scatter(xyz[0], xyz[1], xyz[2], c=pred_c, s=5, alpha=0.8)
    ax2.set_title("Model Prediction", fontsize=14)
    ax2.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
cm, classes = evaluate_model(model, test_loader)
# Out:
# ==================================================
#  Classification Report
# ==================================================
#                      precision    recall  f1-score   support
#
#      0_Intact_Brick     0.1483    0.4751    0.2260      2507
# 1_Material_Spalling     0.9911    0.9553    0.9729    153141
#    2_Moderate_Crack     0.0000    0.0000    0.0000         0
#      3_Severe_Crack     0.0000    0.0000    0.0000         0
#
#            accuracy                         0.9476    155648
#           macro avg     0.2848    0.3576    0.2997    155648
#        weighted avg     0.9775    0.9476    0.9609    155648
#
#
# ==================================================
#  Intersection over Union (IoU)
# ==================================================
# [0_Intact_Brick] IoU: 12.74%
# [1_Material_Spalling] IoU: 94.72%
# [2_Moderate_Crack] IoU: nan%
# [3_Severe_Crack] IoU: nan%
# ------------------------------
# Mean IoU (mIoU): 53.73%

# %%
plot_confusion_matrix(cm, classes)
# Out:
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3650 (\N{THAI CHARACTER SARA O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\671559113.py:13: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3650 (\N{THAI CHARACTER SARA O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
visualize_prediction_3d(model, test_loader)
# Out:
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3636 (\N{THAI CHARACTER SARA I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3612 (\N{THAI CHARACTER PHO PHUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3621 (\N{THAI CHARACTER LO LING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3608 (\N{THAI CHARACTER THO THONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3660 (\N{THAI CHARACTER THANTHAKHAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\babxk\AppData\Local\Temp\ipykernel_2376\605956598.py:32: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3612 (\N{THAI CHARACTER PHO PHUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3614 (\N{THAI CHARACTER PHO PHAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3608 (\N{THAI CHARACTER THO THONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3660 (\N{THAI CHARACTER THANTHAKHAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\babxk\anaconda3\envs\3d-research\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
